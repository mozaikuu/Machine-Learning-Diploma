# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
plt.style.use('seaborn')
# Out:
# C:\Users\ai02\AppData\Local\Temp\ipykernel_15620\736635463.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
ages = [10, 30, 45, 30, 31, 46, 12, 16, 32, 23, 28, 29]

# ,edgecolor='black'

plt.hist(ages,edgecolor='black')

plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
ages = [10, 30, 45, 30, 31, 46, 12, 16, 32, 23, 28, 29]
bi = [10,20,30,40]

# mean = np.mean(ages)
# print(mean)
plt.hist(ages, bins=bi ,edgecolor='black')

# plt.axvline(mean, color = 'red', linewidth = 2)


plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
data = pd.read_csv('500_Person_Gender_Height_Weight_Index.csv')
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
height = data['Height'].max()
height
# Out:
# 199

# %%
height = data['Height'].min()
height
# Out:
# 140

# %%
height = data['Height']
plt.hist(height, edgecolor='black')

plt.title('Height Distribution')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()

# %%
height = data['Height']
bins = [i for i in range(140, 201, 5)]
print(bins)
plt.hist(height, bins = bins, edgecolor='black')

plt.title('Height Distribution')
plt.xlabel('Height')
plt.ylabel('Frequency')
plt.show()
# Out:
# [140, 145, 150, 155, 160, 165, 170, 175, 180, 185, 190, 195]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  500 non-null    object
#  1   Height  500 non-null    int64
#  2   Weight  500 non-null    int64
#  3   Index   500 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
gender_freq = data['Gender'].value_counts()
gender_freq
# Out:
# Female    255
# Male      245
# Name: Gender, dtype: int64

# %%
gender_freq.index
# Out:
# Index(['Female', 'Male'], dtype='object')

# %%
plt.bar( gender_freq.index , gender_freq, color = ['orange', 'blue'] )
plt.show()

# %%
plt.pie(gender_freq, labels = gender_freq.index)
plt.show()
