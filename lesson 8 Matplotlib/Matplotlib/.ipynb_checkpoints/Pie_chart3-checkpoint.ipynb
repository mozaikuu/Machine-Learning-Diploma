# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = [70,20,10,50]
plt.pie(data)
# lab = ['Python', 'Javascript', 'HTML', 'Java']
# plt.pie(data, labels=lab)

plt.title('A Pie Chart')
plt.show()

# %%
data = [70,20,10,50]
labels = ['Python', 'Javascript', 'HTML', 'Java']
# explode = [0.1,0,0.2,0]
# colors= ['yellow','red','green','#DD9804']
plt.pie(data, labels=labels)#,wedgeprops = {'edgecolor': 'black'},colors=colors,explode =explode,startangle=80,autopct="%1.2f%%",rotatelabels=True)

plt.title('A Pie Chart')
plt.show()
