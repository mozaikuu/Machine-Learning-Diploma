# %% [markdown]
# # Part 1: In-Session Exercises

# %% [markdown]
# ### Guidelines for Implementation
# - Tools: Use Python, along with libraries like NumPy, pandas, and matplotlib/seaborn for data manipulation and visualization.
# - Dataset: The dataset can be accessed directly from the provided URL using pandas.read_csv().
# - Solutions: Encourage the use of Jupyter notebooks or similar environments for practical exercises.

# %%
import pandas as pd

data = 'https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/Python/Animals.csv'

animals_df = pd.read_csv(data)

# Display the created dataset
animals_df.head()
# Out:
#             Species  Average Lifespan (Years)           Habitat  \
# 0  African Elephant                        60        Grasslands
# 1      Bengal Tiger                        15           Forests
# 2        Blue Whale                        80             Ocean
# 3       Giant Panda                        20  Temperate Forest
# 4     Komodo Dragon                        30           Islands
#
#   Conservation Status
# 0          Vulnerable
# 1          Endangered
# 2          Endangered
# 3          Vulnerable
# 4          Vulnerable

# %%
animals_df
# Out:
#              Species  Average Lifespan (Years)             Habitat  \
# 0   African Elephant                        60          Grasslands
# 1       Bengal Tiger                        15             Forests
# 2         Blue Whale                        80               Ocean
# 3        Giant Panda                        20    Temperate Forest
# 4      Komodo Dragon                        30             Islands
# 5         Polar Bear                        25              Arctic
# 6            Red Fox                         5             Various
# 7    Emperor Penguin                        20           Antarctic
# 8              Koala                        13  Eucalyptus Forests
# 9          Orangutan                        35         Rainforests
# 10      Snow Leopard                        15     Mountain Ranges
# 11        Bald Eagle                        20  Forests, Seacoasts
# 12      African Lion                        14             Savanna
# 13  Green Sea Turtle                        80     Oceans, Beaches
# 14         Gray Wolf                         8     Forests, Tundra
#
#       Conservation Status
# 0              Vulnerable
# 1              Endangered
# 2              Endangered
# 3              Vulnerable
# 4              Vulnerable
# 5              Vulnerable
# 6           Least Concern
# 7         Near Threatened
# 8              Vulnerable
# 9   Critically Endangered
# 10             Vulnerable
# 11          Least Concern
# 12             Vulnerable
# 13             Endangered
# 14          Least Concern

# %% [markdown]
# ## 1. Descriptive Statistics

# %% [markdown]
# ### 1.1 Basic Statistics
# Calculate the mean, median, and standard deviation of the Average Lifespan (Years).

# %%
animal_mean = animals_df['Average Lifespan (Years)'].mean()
animal_median = animals_df['Average Lifespan (Years)'].median()
animal_std = animals_df['Average Lifespan (Years)'].std()

# %%
print(animal_mean)
print(animal_median)
print(animal_std)
# Out:
# 29.333333333333332
# 20.0
# 24.41798712502927

# %% [markdown]
# ### 1.2 Distribution
# Plot a histogram of the Average Lifespan (Years) column and describe the distribution shape. Identify any outliers.

# %%
import matplotlib.pyplot as plt

plt.hist(animals_df['Average Lifespan (Years)'], bins=25, color='c', edgecolor='black')
plt.xlabel('Average Lifespan (Years)')
plt.ylabel('Count')
plt.title('Distribution of Average Lifespan')
plt.show()

# %% [markdown]
# 60 & 80 are outliers

# %%
# removing outliers

animals_df_fixed = animals_df[animals_df['Average Lifespan (Years)'] < 60]

plt.hist(animals_df_fixed['Average Lifespan (Years)'], bins=20, color='c', edgecolor='black')
plt.xlabel('Average Lifespan (Years)')
plt.ylabel('Count')
plt.title('Distribution of Average Lifespan')
plt.show()

# %% [markdown]
# #### What type of distribution?

# %% [markdown]
# bell curve?

# %% [markdown]
# ## 2. Probability and Probability Distributions

# %% [markdown]
# ### 2.1 Probability Calculation
# What is the probability of randomly selecting a species with an Average Lifespan (Years) greater than 20?

# %%
num_of_species = len(animals_df)
num_species_over_20 = len(animals_df[animals_df['Average Lifespan (Years)'] > 20])

print(num_species_over_20/num_of_species)
# Out:
# 0.4

# %% [markdown]
# ### 2.2 Conditional Probability
# Given that a species lives in a specific Habitat (e.g., 'Forests'), what is the probability that its conservation status is 'Endangered'?

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.2 Conditional Probability
# Given that a species lives in a specific Habitat (e.g., 'Forests'), what is the probability that its conservation status is 'Endangered'?

# %%
# a | b

# forest = animals_df[animals_df['Habitat'] == 'Forests']
forest = animals_df[animals_df['Habitat'].str.contains('Forests')]

# print(forest)

endangered = forest[forest['Conservation Status'] == 'Endangered']

# print(endangered)

print(f"{len(endangered) / len(forest) * 100}%")
# Out:
# 25.0%

# %% [markdown]
# ## 3. Linear Algebra
# ### 3.1 Vector Operations
# Treat Average Lifespan (Years) as a vector and calculate basic statistics such as mean and standard deviation

# %%
mean_lifespan = forest['Average Lifespan (Years)'].mean()
std_dev_lifespan = forest['Average Lifespan (Years)'].std()

print(f"Mean: {mean_lifespan}")
print(f"Standard Deviation: {std_dev_lifespan}")
# Out:
# Mean: 14.0
# Standard Deviation: 4.96655480858378

# %% [markdown]
# ### 3.2 Norm Calculation
# Calculate the Euclidean norm of the vector formed by the Average Lifespan (Years).

# %%
import numpy as np

norm = np.linalg.norm(animals_df['Average Lifespan (Years)'])
norm
# Out:
# 145.78751661236294

# %% [markdown]
# # Soccer Players Data Analysis Homework
# In this homework, you will analyze a dataset of soccer players using various mathematical concepts, including statistics, probability, linear algebra.
# The dataset includes attributes such as Name, Age, Overall, Acceleration, Aggression, and others.

# %%
soccer_df = pd.read_csv("https://raw.githubusercontent.com/Explore-AI/Public-Data/master/Data/fundamentals/football_players.csv",low_memory=False)
soccer_df.head()
# Out:
#                 Name  Age Nationality  Overall Acceleration Aggression  \
# 0  Cristiano Ronaldo   32    Portugal       94       89         63
# 1           L. Messi   30   Argentina       93       92         48
# 2             Neymar   25      Brazil       92       94         56
# 3          L. Suárez   30     Uruguay       92       88         78
# 4           M. Neuer   31     Germany       92       58         29
#
#   Agility Balance Ball control Composure  ... Short passing Shot power  \
# 0  89      63           93        95      ...        83         94
# 1  90      95           95        96      ...        88         85
# 2  96      82           95        92      ...        81         80
# 3  86      60           91        83      ...        83         87
# 4  52      35           48        70      ...        55         25
#
#   Sliding tackle Sprint speed Stamina Standing tackle Strength  Vision  \
# 0         23           91      92              31       80      85
# 1         26           87      73              28       59      90
# 2         33           90      78              24       53      80
# 3         38           77      89              45       80      84
# 4         11           61      44              10       83      70
#
#   Volleys Preferred Positions
# 0  88                  ST LW
# 1  85                     RW
# 2  83                     LW
# 3  88                     ST
# 4  11                     GK
#
# [5 rows x 39 columns]

# %%
soccer_df.columns
# Out:
# Index(['Name', 'Age', 'Nationality', 'Overall', 'Acceleration', 'Aggression',
#        'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving',
#        'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
#        'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing',
#        'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
#        'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed',
#        'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys',
#        'Preferred Positions'],
#       dtype='object')

# %%
cols = ['Age', 'Overall', 'Acceleration', 'Aggression', 'Agility', 'Balance', 'Ball control', 'Composure', 'Crossing', 'Curve',
       'Dribbling', 'Finishing', 'Free kick accuracy', 'GK diving', 'GK handling', 'GK kicking', 'GK positioning', 'GK reflexes',
       'Heading accuracy', 'Interceptions', 'Jumping', 'Long passing', 'Long shots', 'Marking', 'Penalties', 'Positioning', 'Reactions',
       'Short passing', 'Shot power', 'Sliding tackle', 'Sprint speed', 'Stamina', 'Standing tackle', 'Strength', 'Vision', 'Volleys']

soccer_df[cols] = soccer_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %% [markdown]
# ### 1. Descriptive Statistics
# #### 1.1 Basic Statistics
# Calculate the following statistics for the Overall column:
#
# - Mean
# - Median
# - Mode
# - Standard deviation
# - Variance

# %%
soccer_df_mean = soccer_df[cols].mean()
soccer_df_median = soccer_df[cols].median()
soccer_df_mode = soccer_df[cols].mode()
soccer_df_std = soccer_df[cols].std()
soccer_df_var = soccer_df[cols].var()

# %%
print(soccer_df_mean)
print(soccer_df_median)
print(soccer_df_mode)
print(soccer_df_std)
print(soccer_df_var)
# Out:
# Age                    25.144541
# Overall                66.247984
# Acceleration          103.446893
# Aggression             77.599230
# Agility                98.150248
# Balance                86.616911
# Ball control          121.420338
# Composure             103.764995
# Crossing               86.550600
# Curve                  62.586496
# Dribbling             107.087144
# Finishing              93.320972
# Free kick accuracy     62.112993
# GK diving              31.916620
# GK handling            29.673792
# GK kicking             26.373066
# GK positioning         29.035180
# GK reflexes            32.952179
# Heading accuracy       86.884961
# Interceptions          91.004522
# Jumping               104.538213
# Long passing           91.558406
# Long shots             73.818070
# Marking               112.599073
# Penalties              62.450148
# Positioning            82.599107
# Reactions             121.637937
# Short passing         115.298557
# Shot power             83.046796
# Sliding tackle         89.598672
# Sprint speed          119.034849
# Stamina               123.126151
# Standing tackle       109.390425
# Strength              116.040138
# Vision                 91.195878
# Volleys                54.622507
# dtype: float64
# Age                   25.0
# Overall               66.0
# Acceleration          67.0
# Aggression            59.0
# Agility               65.0
# Balance               66.0
# Ball control          63.0
# Composure             60.0
# Crossing              54.0
# Curve                 48.0
# Dribbling             61.0
# Finishing             48.0
# Free kick accuracy    42.0
# GK diving             11.0
# GK handling           11.0
# GK kicking            11.0
# GK positioning        11.0
# GK reflexes           11.0
# Heading accuracy      56.0
# Interceptions         52.0
# Jumping               66.0
# Long passing          56.0
# Long shots            51.0
# Marking               48.0
# Penalties             50.0
# Positioning           55.0
# Reactions             62.0
# Short passing         62.0
# Shot power            59.0
# Sliding tackle        51.0
# Sprint speed          67.0
# Stamina               66.0
# Standing tackle       54.0
# Strength              66.0
# Vision                54.0
# Volleys               44.0
# dtype: float64
#     Age  Overall  Acceleration  Aggression  Agility  Balance  Ball control  \
# 0  25.0     66.0          68.0        70.0     72.0     68.0          64.0
#
#    Composure  Crossing  Curve  ...  Reactions  Short passing  Shot power  \
# 0       60.0      62.0   45.0  ...       64.0           64.0        68.0
#
#    Sliding tackle  Sprint speed  Stamina  Standing tackle  Strength  Vision  \
# 0            62.0          68.0     72.0             66.0      72.0    58.0
#
#    Volleys
# 0     48.0
#
# [1 rows x 36 columns]
# Age                      4.614272
# Overall                  6.987965
# Acceleration           986.386054
# Aggression             768.797300
# Agility                910.809847
# Balance                752.123941
# Ball control          1236.108966
# Composure             1028.086556
# Crossing               912.376407
# Curve                  623.794730
# Dribbling             1110.770999
# Finishing             1070.377057
# Free kick accuracy     649.437032
# GK diving              619.746043
# GK handling            567.678388
# GK kicking             477.741134
# GK positioning         537.041018
# GK reflexes            659.342141
# Heading accuracy       901.886332
# Interceptions         1134.503072
# Jumping               1011.433721
# Long passing           939.293768
# Long shots             804.754381
# Marking               1385.909686
# Penalties              530.479547
# Positioning            928.688631
# Reactions             1161.367097
# Short passing         1157.803920
# Shot power             811.145271
# Sliding tackle        1074.217147
# Sprint speed          1185.940156
# Stamina               1261.551333
# Standing tackle       1286.912547
# Strength              1148.520031
# Vision                 945.840135
# Volleys                523.716920
# dtype: float64
# Age                   2.129151e+01
# Overall               4.883166e+01
# Acceleration          9.729574e+05
# Aggression            5.910493e+05
# Agility               8.295746e+05
# Balance               5.656904e+05
# Ball control          1.527965e+06
# Composure             1.056962e+06
# Crossing              8.324307e+05
# Curve                 3.891199e+05
# Dribbling             1.233812e+06
# Finishing             1.145707e+06
# Free kick accuracy    4.217685e+05
# GK diving             3.840852e+05
# GK handling           3.222588e+05
# GK kicking            2.282366e+05
# GK positioning        2.884131e+05
# GK reflexes           4.347321e+05
# Heading accuracy      8.133990e+05
# Interceptions         1.287097e+06
# Jumping               1.022998e+06
# Long passing          8.822728e+05
# Long shots            6.476296e+05
# Marking               1.920746e+06
# Penalties             2.814086e+05
# Positioning           8.624626e+05
# Reactions             1.348774e+06
# Short passing         1.340510e+06
# Shot power            6.579566e+05
# Sliding tackle        1.153942e+06
# Sprint speed          1.406454e+06
# Stamina               1.591512e+06
# Standing tackle       1.656144e+06
# Strength              1.319098e+06
# Vision                8.946136e+05
# Volleys               2.742794e+05
# dtype: float64

# %% [markdown]
# ### 1.2 Distribution
# Create a box plot for the Age column. Identify the interquartile range (IQR) and any potential outliers.

# %%
df = soccer_df['Age']
df

plt.boxplot(df)
plt.show()

plt.hist(df)
plt.show()

df = soccer_df[soccer_df['Age'] < 35]
# df = soccer_df['Age'] < 35
df = df['Age']

plt.boxplot(df)
plt.show()

plt.hist(df, bins=18)
plt.show()

# %% [markdown]
# ## 2. Probability and Probability Distributions
# ### 2.1 Probability Calculation
# What is the probability that a randomly selected player has an Overall rating of 85 or higher?

# %%
df = len(soccer_df[soccer_df['Overall'] >= 85])
tot = len(soccer_df)

# soccer_df

print(df)
print(tot)
print(df/tot)
# Out:
# 92
# 17981
# 0.005116511873644402

# %% [markdown]
# ### 2.2 Conditional Probability
# Given that a player is older than 30, what is the probability that their Overall rating is above 80?

# %%
old_df = soccer_df[soccer_df['Age'] > 30]
rating_df = old_df[old_df['Overall'] > 80]
old = len(old_df)
rating = len(rating_df)
print(rating/old)
# Out:
# 0.03196527229676401

# %% [markdown]
# ### 2.3 Probability Distribution
# Plot the probability distribution of the Nationality column. Identify the most common nationality and its probability.

# %%
# plt.hist(soccer_df['Nationality'], bins=20)
# plt.show()

# Count the occurrences of each nationality
nationality_counts = soccer_df['Nationality'].value_counts()

print(nationality_counts)

# Plot the distribution
plt.figure(figsize=(20,10))
nationality_counts.plot(kind='bar')

plt.title('Distribution of Nationalities')
plt.xlabel('Nationality')
plt.ylabel('Count')

plt.show()
# Out:
# Nationality
# England                 1630
# Germany                 1140
# Spain                   1019
# France                   978
# Argentina                965
# Brazil                   812
# Italy                    799
# Colombia                 592
# Japan                    469
# Netherlands              429
# Republic of Ireland      417
# United States            381
# Chile                    375
# Sweden                   368
# Portugal                 367
# Mexico                   360
# Denmark                  346
# Poland                   337
# Norway                   333
# Korea Republic           330
# Saudi Arabia             329
# Russia                   306
# Scotland                 300
# Turkey                   291
# Belgium                  272
# Austria                  266
# Switzerland              233
# Australia                227
# Uruguay                  153
# Serbia                   133
# Senegal                  129
# Nigeria                  126
# Wales                    123
# Ghana                    117
# Croatia                  109
# Ivory Coast              101
# Greece                    98
# Cameroon                  86
# Northern Ireland          86
# Morocco                   78
# South Africa              77
# Czech Republic            73
# Paraguay                  69
# Slovenia                  65
# Slovakia                  64
# Finland                   62
# Romania                   59
# DR Congo                  58
# Algeria                   57
# Bosnia Herzegovina        55
# Canada                    55
# Iceland                   53
# Venezuela                 51
# Ukraine                   49
# Mali                      46
# New Zealand               38
# Jamaica                   37
# Ecuador                   37
# Hungary                   37
# Albania                   35
# Bulgaria                  33
# Kosovo                    32
# Egypt                     32
# Tunisia                   31
# Georgia                   31
# Peru                      30
# India                     30
# Bolivia                   30
# China PR                  30
# Costa Rica                29
# Montenegro                25
# Guinea                    25
# Cape Verde                22
# Congo                     22
# Iran                      17
# FYR Macedonia             17
# Panama                    16
# Guinea Bissau             16
# Gambia                    15
# Angola                    15
# Burkina Faso              14
# Benin                     14
# Armenia                   14
# Haiti                     14
# Honduras                  13
# Israel                    12
# Lithuania                 12
# Gabon                     12
# Curacao                   11
# Zimbabwe                  11
# Cyprus                    11
# Trinidad & Tobago          9
# Iraq                       9
# Sierra Leone               9
# Comoros                    9
# Belarus                    9
# Estonia                    8
# Togo                       8
# Luxembourg                 8
# Latvia                     7
# Azerbaijan                 7
# Kenya                      7
# Zambia                     7
# Syria                      6
# Moldova                    6
# Qatar                      6
# Korea DPR                  6
# Equatorial Guinea          6
# Faroe Islands              6
# Guyana                     5
# Antigua & Barbuda          5
# Uzbekistan                 5
# Lebanon                    5
# Central African Rep.       4
# Palestine                  4
# Uganda                     4
# Montserrat                 4
# Bermuda                    4
# Madagascar                 4
# Afghanistan                3
# Philippines                3
# Dominican Republic         3
# Malta                      3
# Niger                      3
# St Kitts Nevis             3
# Liechtenstein              3
# Kazakhstan                 3
# Suriname                   3
# Mozambique                 3
# Sudan                      2
# Liberia                    2
# Ethiopia                   2
# Puerto Rico                2
# Namibia                    2
# Thailand                   2
# Gibraltar                  2
# Chad                       2
# El Salvador                2
# Mauritania                 2
# Kuwait                     2
# New Caledonia              2
# Libya                      2
# Tanzania                   2
# Cuba                       2
# Sri Lanka                  1
# Vietnam                    1
# Turkmenistan               1
# Kyrgyzstan                 1
# Brunei Darussalam          1
# San Marino                 1
# St Lucia                   1
# Swaziland                  1
# Guam                       1
# Burundi                    1
# Belize                     1
# Grenada                    1
# São Tomé & Príncipe        1
# Barbados                   1
# Mauritius                  1
# Somalia                    1
# Fiji                       1
# Eritrea                    1
# Guatemala                  1
# Oman                       1
# Hong Kong                  1
# Name: count, dtype: int64

# %%
# Get the first nationality
first_nationality = soccer_df['Nationality'].value_counts().idxmax()

# Count the occurrences of the first nationality
first_nationality_count = soccer_df['Nationality'].value_counts()[first_nationality]

# Calculate the total count of all nationalities
total_count = soccer_df['Nationality'].count()

# Calculate the probability
probability = first_nationality_count / total_count

print(f"The probability of {first_nationality} occurring is {probability}")
# Out:
# The probability of England occurring is 0.09065124297869974

# %% [markdown]
# ## 3. Correlation
# ### 3.1 Correlation Coefficient
# Calculate the Pearson correlation coefficient between Acceleration and Sprint speed. Interpret the result.

# %%
pearson_corr = soccer_df['Acceleration'].corr(soccer_df['Sprint speed'], method='pearson')

print(f"The Pearson correlation between var1 and var2 is {pearson_corr}")
# Out:
# The Pearson correlation between var1 and var2 is 0.6893951136703762

# %% [markdown]
# ## 4. Linear Algebra
# ### 4.1 Vector Operations
# Treat the Acceleration and Sprint speed columns as vectors. Calculate the dot product and the cosine similarity between these vectors.

# %%
acc = soccer_df['Acceleration']
spr = soccer_df['Sprint speed']

# acc = np.array(acc)
# spr = np.array(spr)

# print(acc)
# print(spr)

dot = np.dot(acc, spr)

print(dot)

mag_acc = np.linalg.norm(soccer_df['Acceleration'])
mag_spr = np.linalg.norm(soccer_df['Sprint speed'])

print(mag_acc)
print(mag_spr)

cos_sim = dot / (mag_acc * mag_spr)

print("The dot product between var1 and var2 is", dot)
print("The cosine similarity between var1 and var2 is", cos_sim)
# Out:
# nan
# nan
# nan
# The dot product between var1 and var2 is nan
# The cosine similarity between var1 and var2 is nan

# %% [markdown]
# ### 4.2 Norm Calculation
# Compute the Euclidean norm of the vector formed by the Strength column.

# %%
# print(soccer_df['Strength'])
Strength = soccer_df['Strength']

# print(Strength)

Strength = np.array(Strength)

# print(Strength)

euclidean_norm = np.linalg.norm(Strength)

print(euclidean_norm)

print(f"The Euclidean norm of the 'Strength' column is {euclidean_norm}")
# Out:
# [80. 59. 53. ... 32. 46. 67.]
# nan
# The Euclidean norm of the 'Strength' column is nan

# %% [markdown]
# # Submission Guidelines
# - Provide the code used for calculations and analysis.
# - Include visualizations and clearly label them.
# - Interpret the results and provide insights for each section.
# - Submit the work by 1-AUG (10 PM).
#
# **Good luck and happy analyzing! If you have any questions, feel free to ask.**
