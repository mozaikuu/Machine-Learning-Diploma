# %%
import pandas as pd
import numpy as np
from numpy.random import randn
np.random.seed(12)

# %%
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    3
# 1    3
# 2    6
# 3    5
# 4    1
# 5    2
# 6    3
# 7    3
# 8    4
# 9    0
# dtype: int32

# %%
df = pd.DataFrame(
     randn(6,3),
     index=['A','B','C','D','E','F'],
     columns=['C1','C2','C3'])

# %%
df
# Out:
#          C1        C2        C3
# A  0.873135  0.910565  1.047646
# B -1.189639 -1.240562  0.055302
# C  0.212211 -0.345324  1.202163
# D -2.205594 -1.080765 -0.086147
# E  0.493514 -1.164466 -2.399881
# F -0.610064 -2.233480  0.794752

# %%
df.head(2)
# Out:
#          C1        C2        C3
# A  0.873135  0.910565  1.047646
# B -1.189639 -1.240562  0.055302

# %%
df.tail(3)
# Out:
#          C1        C2        C3
# D -2.205594 -1.080765 -0.086147
# E  0.493514 -1.164466 -2.399881
# F -0.610064 -2.233480  0.794752

# %%
df<=0
# Out:
#       C1     C2     C3
# A  False  False  False
# B   True   True  False
# C  False   True  False
# D   True   True   True
# E  False   True   True
# F   True   True  False

# %%
df_2 =df[df<=0]

# %%
df_2
# Out:
#          C1        C2        C3
# A       NaN       NaN       NaN
# B -1.189639 -1.240562       NaN
# C       NaN -0.345324       NaN
# D -2.205594 -1.080765 -0.086147
# E       NaN -1.164466 -2.399881
# F -0.610064 -2.233480       NaN

# %%
df
# Out:
#          C1        C2        C3
# A  0.873135  0.910565  1.047646
# B -1.189639 -1.240562  0.055302
# C  0.212211 -0.345324  1.202163
# D -2.205594 -1.080765 -0.086147
# E  0.493514 -1.164466 -2.399881
# F -0.610064 -2.233480  0.794752

# %%
df_2 =df[df['C3']>0]

# %%
df_2
# Out:
#          C1        C2        C3
# A  0.873135  0.910565  1.047646
# B -1.189639 -1.240562  0.055302
# C  0.212211 -0.345324  1.202163
# F -0.610064 -2.233480  0.794752

# %%
df_2 =df[(df['C3']<=0) & df['C1']>=0.3]

# %%
df_2
# Out:
#          C1        C2        C3
# D -2.205594 -1.080765 -0.086147
# E  0.493514 -1.164466 -2.399881

# %%
df_2 =df[(df['C3']<=0) | (df['C1']>=0.5)]

# %%
df_2
# Out:
#          C1        C2        C3
# A  0.873135  0.910565  1.047646
# D -2.205594 -1.080765 -0.086147
# E  0.493514 -1.164466 -2.399881

# %%
df
# Out:
#          C1        C2        C3
# A  0.873135  0.910565  1.047646
# B -1.189639 -1.240562  0.055302
# C  0.212211 -0.345324  1.202163
# D -2.205594 -1.080765 -0.086147
# E  0.493514 -1.164466 -2.399881
# F -0.610064 -2.233480  0.794752

# %%
df_2 =df[(df['C3']<=0) | (df['C1']>=0.5)]['C2']

# %%
df_2
# Out:
# A    0.910565
# D   -1.080765
# E   -1.164466
# Name: C2, dtype: float64

# %%
df_2 =df[(df['C3']<=0) | df['C1']>=0.5].loc['B']

# %%
df_2
# Out:
# C1   -1.189639
# C2   -1.240562
# C3    0.055302
# Name: B, dtype: float64
