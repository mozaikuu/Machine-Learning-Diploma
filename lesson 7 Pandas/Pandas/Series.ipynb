# %%
import pandas as pd

# %%
pd.Series

# %%
# !pip install pandas

# %%
header = ["Name","Age", "Weight"]
values = ["Amira", 24, 65]
my_ser = pd.Series(data=values, index=header)

# %%
my_ser
# Out:
# Name      Amira
# Age          24
# Weight       65
# dtype: object

# %%
my_ser["Age"]
# Out:
# 24

# %%
my_ser2= pd.Series(values)

# %%
my_ser2
# Out:
# 0    Amira
# 1       24
# 2       65
# dtype: object

# %%
sem_1= pd.Series(data=[50,25], index=["Math","Physics"])
sem_2= pd.Series(data=[45,85,35], index=["Algebra","CS","Physics"])

# %%
sem_1
# Out:
# Math       50
# Physics    25
# dtype: int64

# %%
sem_2
# Out:
# Algebra    45
# CS         85
# Physics    35
# dtype: int64

# %%
all_sems= sem_1 + sem_2

# %%
all_sems
# Out:
# Algebra     NaN
# CS          NaN
# Math        NaN
# Physics    60.0
# dtype: float64
